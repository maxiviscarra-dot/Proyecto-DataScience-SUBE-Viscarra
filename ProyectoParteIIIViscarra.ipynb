# %% [markdown]
# ## ProyectoParteIIIViscarra

# %%
# Proyecto Parte III - Viscarra

## 1. Carga y Exploración de Datos

```python
import pandas as pd

df = pd.read_csv("dat-ab-usos-2024.csv")
df.head()
```

---

## 2. Preprocesamiento

```python
df['CANTIDAD'] = pd.to_numeric(df['CANTIDAD'], errors='coerce')
df_model = df.dropna(subset=['CANTIDAD'])
```

---

## 3. Codificación de Variables y Selección de Features

```python
df_model = pd.get_dummies(df_model[['TIPO_TRANSPORTE', 'JURISDICCION', 'AMBA', 'CANTIDAD']], drop_first=True)
X = df_model.drop('CANTIDAD', axis=1)
y = df_model['CANTIDAD']

from sklearn.feature_selection import SelectKBest, f_regression
selector = SelectKBest(score_func=f_regression, k='all')
X_new = selector.fit_transform(X, y)
```

---

## 4. División en Train y Test

```python
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)
```

---

## 5. Regresión Lineal

```python
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit(X_train, y_train)
y_pred = modelo.predict(X_test)
```

---

## 6. Métricas

```python
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
```

---

## 7. Conclusión

El modelo de regresión lineal explica un 32.5% de la variación en la cantidad de usos de transporte según el tipo, jurisdicción y si pertenece al AMBA o no. Aunque el modelo es simple, ofrece una primera aproximación al comportamiento del dataset. Puede mejorarse con más variables o análisis no supervisado como clustering.
